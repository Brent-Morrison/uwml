# %%
import numpy as np
import pandas as pd
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
train = pd.read_csv('gdrive/My Drive/uwml/kc_house_train_data.csv')

# %%
train
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 0      7129300520  20141013T000000  ...           1340        5650
# 1      6414100192  20141209T000000  ...           1690        7639
# 2      5631500400  20150225T000000  ...           2720        8062
# 3      2487200875  20141209T000000  ...           1360        5000
# 4      1954400510  20150218T000000  ...           1800        7503
# ...           ...              ...  ...            ...         ...
# 17379  7936000429  20150326T000000  ...           2050        6200
# 17380  2997800021  20150219T000000  ...           1330        1265
# 17381   263000018  20140521T000000  ...           1530        1509
# 17382   291310100  20150116T000000  ...           1410        1287
# 17383  1523300157  20141015T000000  ...           1020        1357
#
# [17384 rows x 21 columns]

# %%
train.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
# Regression slope and intercept

def simple_linear_regression(input_feature, output):
  y = output.values
  x = input_feature.values
  num = np.mean(x * y) - (np.mean(x) * np.mean(y))
  den = np.mean(x * x) - (np.mean(x) * np.mean(x))
  slope = num/den
  intercept = np.mean(y) - slope * np.mean(x)
  return(intercept, slope)

# %%
# Test
x = [0,1,2,3,4]
y = [1,3,7,13,21]
x = pd.Series(x)
y = pd.Series(y)

model = simple_linear_regression(x, y)
print(model[0])
print(model[1])
# Out:
# -1.0
# 5.0

# %%
train_y = train['price']
train_x = train['sqft_living']
train_x
# Out:
# 0        1180
# 1        2570
# 2         770
# 3        1960
# 4        1680
#          ...
# 17379    3510
# 17380    1310
# 17381    1530
# 17382    1600
# 17383    1020
# Name: sqft_living, Length: 17384, dtype: int64

# %%
model = simple_linear_regression(train_x, train_y)
squarefeet_intercept = model[0]
squarefeet_slope = model[1]

print(squarefeet_intercept)
print(squarefeet_slope)
# Out:
# -47116.07907289488
# 281.95883963034294

# %%
# Predictions
def get_regression_predictions(input_feature, intercept, slope):
  x = input_feature
  predicted_output = intercept + (slope * x)
  return(predicted_output)

# %%
# Q1
get_regression_predictions(2650, squarefeet_intercept, squarefeet_slope)
# Out:
# 700074.8459475139

# %%
# RSS function
def get_residual_sum_of_squares(input_feature, output, intercept, slope):
  x = input_feature.values
  y = output.values
  yhat =  intercept + (slope * x)
  e = yhat - y
  RSS = np.sum(e * e)
  return(RSS)

# %%
get_residual_sum_of_squares(train['sqft_living'], train['price'], squarefeet_intercept, squarefeet_slope)
# Out:
# 1201918354177283.0

# %%
# Model for bedrooms
model = simple_linear_regression(train['bedrooms'], train_y)
bedrooms_intercept = model[0]
bedrooms_slope = model[1]

print(bedrooms_intercept)
print(bedrooms_slope)
# Out:
# 109473.17762295791
# 127588.95293398833

# %%
# Test data
test = pd.read_csv('gdrive/My Drive/uwml/kc_house_test_data.csv')
test
# Out:
#               id             date  ...  sqft_living15  sqft_lot15
# 0      114101516  20140528T000000  ...           1780       12697
# 1     9297300055  20150124T000000  ...           2140        4000
# 2     1202000200  20141103T000000  ...           1030        4705
# 3     8562750320  20141110T000000  ...           2580        3980
# 4     7589200193  20141110T000000  ...           1570        5080
# ...          ...              ...  ...            ...         ...
# 4224  8672200110  20150317T000000  ...           3030        7980
# 4225  5087900040  20141017T000000  ...           2530        5988
# 4226  3448900210  20141014T000000  ...           2520        6023
# 4227  6600060120  20150223T000000  ...           1830        7200
# 4228  1523300141  20140623T000000  ...           1020        2007
#
# [4229 rows x 21 columns]

# %%
sq_feet_test_rss = get_residual_sum_of_squares(test['sqft_living'], test['price'], squarefeet_intercept, squarefeet_slope)
bedrooms_test_rss = get_residual_sum_of_squares(test['bedrooms'], test['price'], bedrooms_intercept, bedrooms_slope)

print(sq_feet_test_rss/1e12)
print(bedrooms_test_rss/1e12)
# Out:
# 275.40293361781215
# 493.364585960301
