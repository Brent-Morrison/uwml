# %% [markdown]
# # Build a song recommender system

# %%
# !pip install turicreate
# Out:
# ...
#      |████████████████████████████████| 91.9MB 66kB/s
# ...
#      |████████████████████████████████| 2.1MB 56.3MB/s
# ...
#      |████████████████████████████████| 86.3MB 74kB/s
# ...
#      |████████████████████████████████| 20.2MB 1.2MB/s
# ...
#      |████████████████████████████████| 3.4MB 52.3MB/s
# ...
#      |████████████████████████████████| 3.8MB 17.6MB/s
# ...
#      |████████████████████████████████| 450kB 42.8MB/s
# ...
# ERROR: fastai 0.7.0 has requirement torch<0.4, but you'll have torch 1.4.0 which is incompatible.
# ERROR: tensorboard 2.0.2 has requirement grpcio>=1.24.3, but you'll have grpcio 1.15.0 which is incompatible.
# ...
#   Found existing installation: Pillow 4.3.0
#     Uninstalling Pillow-4.3.0:
#       Successfully uninstalled Pillow-4.3.0
#   Found existing installation: google-auth-oauthlib 0.4.0
#     Uninstalling google-auth-oauthlib-0.4.0:
#       Successfully uninstalled google-auth-oauthlib-0.4.0
#   Found existing installation: tensorboard 2.1.0
#     Uninstalling tensorboard-2.1.0:
# ...

# %%
import turicreate

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Load some music data

# %%
song_data = turicreate.SFrame('gdrive/My Drive/uwml/song_data.sframe')

# %% [markdown]
# # Explore our data

# %%
song_data
# Out:
# Columns:
# 	user_id	str
# 	song_id	str
# 	listen_count	int
# 	title	str
# 	artist	str
# 	song	str
#
# Rows: 1116609
#
# Data:
# +-------------------------------+--------------------+--------------+
# |            user_id            |      song_id       | listen_count |
# +-------------------------------+--------------------+--------------+
# | b80344d063b5ccb3212f76538f... | SOAKIMP12A8C130995 |      1       |
# | b80344d063b5ccb3212f76538f... | SOBBMDR12A8C13253B |      2       |
# | b80344d063b5ccb3212f76538f... | SOBXHDL12A81C204C0 |      1       |
# | b80344d063b5ccb3212f76538f... | SOBYHAJ12A6701BF1D |      1       |
# | b80344d063b5ccb3212f76538f... | SODACBL12A8C13C273 |      1       |
# | b80344d063b5ccb3212f76538f... | SODDNQT12A6D4F5F7E |      5       |
# | b80344d063b5ccb3212f76538f... | SODXRTY12AB0180F3B |      1       |
# | b80344d063b5ccb3212f76538f... | SOFGUAY12AB017B0A8 |      1       |
# | b80344d063b5ccb3212f76538f... | SOFRQTD12A81C233C0 |      1       |
# ...

# %% [markdown]
# ## Show the most popular songs in the dataset

# %%
song_data['song'].show()
# Out:
# Materializing SArray
# ...

# %% [markdown]
# # Count the number of unique users in the data

# %%
users = song_data['user_id'].unique()

# %%
len(users)
# Out:
# 66346

# %% [markdown]
# # Create a song recommender

# %%
train_data,test_data = song_data.random_split(.8,seed=0)

# %% [markdown]
# ## Create a very simple popularity recommender

# %%
popularity_model = turicreate.popularity_recommender.create(train_data,
                                                           user_id = 'user_id',
                                                           item_id = 'song')
# Out:
# ...
#  To use one of these as a rating column, specify the column name to be used as target
#     and use a method that allows the use of a target.
# Preparing data set.
#     Data has 893580 observations with 66085 users and 9952 items.
#     Data prepared in: 1.41545s
# 893580 observations to process; with 9952 unique items.

# %% [markdown]
# ## Use the popularity model to make some predictions

# %%
popularity_model.recommend(users=[users[0]])
# Out:
# Columns:
# 	user_id	str
# 	song	str
# 	score	float
# 	rank	int
#
# Rows: 10
#
# Data:
# +-------------------------------+--------------------------------+--------+------+
# |            user_id            |              song              | score  | rank |
# +-------------------------------+--------------------------------+--------+------+
# | c66c10a9567f0d82ff31441a9f... |    Sehr kosmisch - Harmonia    | 4754.0 |  1   |
# | c66c10a9567f0d82ff31441a9f... |          Undo - Björk          | 4227.0 |  2   |
# | c66c10a9567f0d82ff31441a9f... | You're The One - Dwight Yoakam | 3781.0 |  3   |
# | c66c10a9567f0d82ff31441a9f... | Dog Days Are Over (Radio E...  | 3633.0 |  4   |
# | c66c10a9567f0d82ff31441a9f... |    Revelry - Kings Of Leon     | 3527.0 |  5   |
# | c66c10a9567f0d82ff31441a9f... | Horn Concerto No. 4 in E f...  | 3161.0 |  6   |
# | c66c10a9567f0d82ff31441a9f... |     Secrets - OneRepublic      | 3148.0 |  7   |
# ...

# %%
popularity_model.recommend(users=[users[1]])
# Out:
# Columns:
# 	user_id	str
# 	song	str
# 	score	float
# 	rank	int
#
# Rows: 10
#
# Data:
# +-------------------------------+--------------------------------+--------+------+
# |            user_id            |              song              | score  | rank |
# +-------------------------------+--------------------------------+--------+------+
# | 02f015d32ac2cd1e52d26e3ec3... |    Sehr kosmisch - Harmonia    | 4754.0 |  1   |
# | 02f015d32ac2cd1e52d26e3ec3... |          Undo - Björk          | 4227.0 |  2   |
# | 02f015d32ac2cd1e52d26e3ec3... | You're The One - Dwight Yoakam | 3781.0 |  3   |
# | 02f015d32ac2cd1e52d26e3ec3... | Dog Days Are Over (Radio E...  | 3633.0 |  4   |
# | 02f015d32ac2cd1e52d26e3ec3... |    Revelry - Kings Of Leon     | 3527.0 |  5   |
# | 02f015d32ac2cd1e52d26e3ec3... | Horn Concerto No. 4 in E f...  | 3161.0 |  6   |
# | 02f015d32ac2cd1e52d26e3ec3... |     Secrets - OneRepublic      | 3148.0 |  7   |
# ...

# %% [markdown]
# # Build a recommender with personalization

# %%
personalized_model = turicreate.item_similarity_recommender.create(train_data,
                                                                  user_id = 'user_id',
                                                                  item_id = 'song')
# Out:
# ...
#  To use one of these as a rating column, specify the column name to be used as target
#     and use a method that allows the use of a target.
# Preparing data set.
#     Data has 893580 observations with 66085 users and 9952 items.
#     Data prepared in: 1.43924s
# Training model from provided data.
# Gathering per-item and per-user statistics.
# +--------------------------------+------------+
# | Elapsed Time (Item Statistics) | % Complete |
# +--------------------------------+------------+
# | 1.483ms                        | 1.5        |
# | 51.54ms                        | 100        |
# +--------------------------------+------------+
# Setting up lookup tables.
# Processing data in one pass using dense lookup tables.
# +-------------------------------------+------------------+-----------------+
# | Elapsed Time (Constructing Lookups) | Total % Complete | Items Processed |
# +-------------------------------------+------------------+-----------------+
# ...

# %% [markdown]
# ## Apply personalized model to make song recommendations

# %%
personalized_model.recommend(users=[users[0]])
# Out:
# Columns:
# 	user_id	str
# 	song	str
# 	score	float
# 	rank	int
#
# Rows: 10
#
# Data:
# +-------------------------------+--------------------------------+
# |            user_id            |              song              |
# +-------------------------------+--------------------------------+
# | c66c10a9567f0d82ff31441a9f... | Cuando Pase El Temblor - S...  |
# | c66c10a9567f0d82ff31441a9f... | Fireflies - Charttraxx Karaoke |
# | c66c10a9567f0d82ff31441a9f... | Love Is A Losing Game - Am...  |
# | c66c10a9567f0d82ff31441a9f... |        Marry Me - Train        |
# | c66c10a9567f0d82ff31441a9f... |     Secrets - OneRepublic      |
# | c66c10a9567f0d82ff31441a9f... |    Sehr kosmisch - Harmonia    |
# | c66c10a9567f0d82ff31441a9f... | Te Hacen Falta Vitaminas -...  |
# | c66c10a9567f0d82ff31441a9f... | OMG - Usher featuring will...  |
# | c66c10a9567f0d82ff31441a9f... | Y solo se me ocurre amarte...  |
# | c66c10a9567f0d82ff31441a9f... |   No Dejes Que... - Caifanes   |
# ...

# %%
personalized_model.recommend(users=[users[1]])
# Out:
# Columns:
# 	user_id	str
# 	song	str
# 	score	float
# 	rank	int
#
# Rows: 10
#
# Data:
# +-------------------------------+--------------------------------+
# |            user_id            |              song              |
# +-------------------------------+--------------------------------+
# | 02f015d32ac2cd1e52d26e3ec3... | Where The Boat Leaves From...  |
# | 02f015d32ac2cd1e52d26e3ec3... | Different Kind Of Fine (Al...  |
# | 02f015d32ac2cd1e52d26e3ec3... | Jolene (Album) - Zac Brown...  |
# | 02f015d32ac2cd1e52d26e3ec3... | Sic 'Em On A Chicken (Albu...  |
# | 02f015d32ac2cd1e52d26e3ec3... | Who's Kissing You Tonight ...  |
# | 02f015d32ac2cd1e52d26e3ec3... |  What Country Is - Luke Bryan  |
# | 02f015d32ac2cd1e52d26e3ec3... | Highway 20 Ride (Album) - ...  |
# | 02f015d32ac2cd1e52d26e3ec3... |       Do I - Luke Bryan        |
# | 02f015d32ac2cd1e52d26e3ec3... | One Fine Wire - Colbie Caillat |
# | 02f015d32ac2cd1e52d26e3ec3... | Midnight Bottle - Colbie C...  |
# ...

# %% [markdown]
# # Apply model to find similar songs in the data set

# %%
personalized_model.get_similar_items(['With Or Without You - U2'])
# Out:
# Columns:
# 	song	str
# 	similar	str
# 	score	float
# 	rank	int
#
# Rows: 10
#
# Data:
# +--------------------------+-------------------------------+-----------------+
# |           song           |            similar            |      score      |
# +--------------------------+-------------------------------+-----------------+
# | With Or Without You - U2 | I Still Haven't Found What... |  0.042857170105 |
# | With Or Without You - U2 | Hold Me_ Thrill Me_ Kiss M... | 0.0337349176407 |
# | With Or Without You - U2 |    Window In The Skies - U2   | 0.0328358411789 |
# | With Or Without You - U2 |          Vertigo - U2         | 0.0300751924515 |
# | With Or Without You - U2 |   Sunday Bloody Sunday - U2   | 0.0271317958832 |
# | With Or Without You - U2 |            Bad - U2           | 0.0251798629761 |
# | With Or Without You - U2 |     A Day Without Me - U2     | 0.0237154364586 |
# | With Or Without You - U2 | Another Time Another Place... | 0.0203251838684 |
# ...

# %%
personalized_model.get_similar_items(['Chan Chan (Live) - Buena Vista Social Club'])
# Out:
# Columns:
# 	song	str
# 	similar	str
# 	score	float
# 	rank	int
#
# Rows: 10
#
# Data:
# +-------------------------------+--------------------------------+
# |              song             |            similar             |
# +-------------------------------+--------------------------------+
# | Chan Chan (Live) - Buena V... | Murmullo - Buena Vista Soc...  |
# | Chan Chan (Live) - Buena V... | La Bayamesa - Buena Vista ...  |
# | Chan Chan (Live) - Buena V... | Amor de Loca Juventud - Bu...  |
# | Chan Chan (Live) - Buena V... |   Diferente - Gotan Project    |
# | Chan Chan (Live) - Buena V... |       Mistica - Orishas        |
# | Chan Chan (Live) - Buena V... | Hotel California - Gipsy Kings |
# | Chan Chan (Live) - Buena V... |     Nací Orishas - Orishas     |
# | Chan Chan (Live) - Buena V... |    Le Moulin - Yann Tiersen    |
# | Chan Chan (Live) - Buena V... |     Gitana - Willie Colon      |
# | Chan Chan (Live) - Buena V... |    Criminal - Gotan Project    |
# ...

# %% [markdown]
# # Compare the models quantitatively
# We now formally compare the popularity and the personalized models using precision-recall curves.

# %%
model_performance = turicreate.recommender.util.compare_models(test_data, [popularity_model, personalized_model], user_sample=.05)
# Out:
# compare_models: using 2931 users to estimate model performance
# PROGRESS: Evaluate model M0
# recommendations finished on 1000/2931 queries. users per second: 2941.26
# recommendations finished on 2000/2931 queries. users per second: 2961.09
# WARNING:root:Model trained without a target. Skipping RMSE computation.
# Precision and recall summary statistics by cutoff
# +--------+-----------------+------------------+
# | cutoff |  mean_precision |   mean_recall    |
# +--------+-----------------+------------------+
# |   1    |  0.021494370522 | 0.00501146376274 |
# |   2    |  0.022176731491 | 0.0109255125632  |
# |   3    | 0.0213806436938 | 0.0156519823101  |
# |   4    | 0.0204708290686 | 0.0193596122972  |
# |   5    | 0.0190378710338 | 0.0229738361263  |
# |   6    | 0.0179688388491 | 0.0258145698269  |
# |   7    |  0.017107764293 | 0.0290396769158  |
# |   8    | 0.0159075400887 | 0.0314953640696  |
# |   9    | 0.0156943022859 | 0.0351693190997  |
# ...

# %% [markdown]
# The table shows that the personalized model provides much better performance.

# %%
print('KW' , len(song_data[song_data['artist'] == 'Kanye West'].unique()))
print('FF' , len(song_data[song_data['artist'] == 'Foo Fighters'].unique()))
print('TS' , len(song_data[song_data['artist'] == 'Taylor Swift'].unique()))
print('LG' , len(song_data[song_data['artist'] == 'Lady GaGa'].unique()))
# Out:
# ('KW', 3775)
# ('FF', 3429)
# ('TF', 6227)
# ('LG', 4129)

# %%
song_data.groupby(key_column_names='artist', operations={'total_listen_count': turicreate.aggregate.SUM('listen_count')}).sort(key_column_names='total_listen_count', ascending=False)
# Out:
# Columns:
# 	artist	str
# 	total_listen_count	int
#
# Rows: 3375
#
# Data:
# +------------------------+--------------------+
# |         artist         | total_listen_count |
# +------------------------+--------------------+
# |     Kings Of Leon      |       43218        |
# |     Dwight Yoakam      |       40619        |
# |         Björk          |       38889        |
# |        Coldplay        |       35362        |
# | Florence + The Machine |       33387        |
# |     Justin Bieber      |       29715        |
# |    Alliance Ethnik     |       26689        |
# |      OneRepublic       |       25754        |
# |         Train          |       25402        |
# |     The Black Keys     |       22184        |
# +------------------------+--------------------+
# [3375 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
song_data.groupby(key_column_names='artist', operations={'total_listen_count': turicreate.aggregate.SUM('listen_count')}).sort(key_column_names='total_listen_count', ascending=True)
# Out:
# Columns:
# 	artist	str
# 	total_listen_count	int
#
# Rows: 3375
#
# Data:
# +-------------------------------+--------------------+
# |             artist            | total_listen_count |
# +-------------------------------+--------------------+
# |        William Tabbert        |         14         |
# |         Reel Feelings         |         24         |
# | Beyoncé feat. Bun B and Sl... |         26         |
# |             Diplo             |         30         |
# |         Boggle Karaoke        |         30         |
# |         harvey summers        |         31         |
# |             Nâdiya            |         36         |
# |          Jody Bernal          |         38         |
# |        Aneta Langerova        |         38         |
# | Kanye West / Talib Kweli /... |         38         |
# +-------------------------------+--------------------+
# [3375 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# ...
